# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def u(x):
    #runge function
    return 1/(1+50*(0.5-x)**2)

# %%
x=linspace(0,1,1025)

# %%
plot(x,u(x))
